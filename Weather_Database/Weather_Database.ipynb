# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nishihara
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | cherskiy
# Processing Record 4 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | luebo
# Processing Record 7 of Set 1 | vestmannaeyjar
# Processing Record 8 of Set 1 | rauma
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | kieta
# Processing Record 12 of Set 1 | hearst
# Processing Record 13 of Set 1 | karratha
# Processing Record 14 of Set 1 | port lincoln
# Processing Record 15 of Set 1 | shasta lake
# Processing Record 16 of Set 1 | port blair
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | airai
# Processing Record 20 of Set 1 | inta
# Processing Record 21 of Set 1 | kondinskoye
# Processing Record 22 of Set 1 | santo antonio do ica
# Processing Record 23 of Set 1 | poum
# Processing Record 24 of Set 1 | ranong
# Processing Record 25 of Set 1 | veraval
# Processing Record 26 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 1 | belmonte
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | remedios
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | cabo san lucas
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | walvis bay
# Processing Record 37 of Set 1 | misratah
# Processing Record 38 of Set 1 | jalu
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | maralal
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | mangrol
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | cherusti
# Processing Record 47 of Set 1 | otjimbingwe
# Processing Record 48 of Set 1 | haines junction
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | comodoro rivadavia
# Processing Record 2 of Set 2 | xinqing
# Processing Record 3 of Set 2 | bredasdorp
# Processing Record 4 of Set 2 | saskylakh
# Processing Record 5 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 2 | tecoanapa
# Processing Record 7 of Set 2 | lodja
# Processing Record 8 of Set 2 | srednekolymsk
# Processing Record 9 of Set 2 | rawson
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | yar-sale
# Processing Record 12 of Set 2 | sataua
# City not found. Skipping...
# Processing Record 13 of Set 2 | anito
# Processing Record 14 of Set 2 | suksun
# Processing Record 15 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 2 | pangkalanbuun
# Processing Record 17 of Set 2 | la ronge
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | ruian
# City not found. Skipping...
# Processing Record 20 of Set 2 | vardo
# Processing Record 21 of Set 2 | shimoda
# Processing Record 22 of Set 2 | victoria
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | springbok
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | kidal
# Processing Record 28 of Set 2 | kruisfontein
# Processing Record 29 of Set 2 | zemio
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | taoudenni
# Processing Record 32 of Set 2 | isangel
# Processing Record 33 of Set 2 | burnie
# Processing Record 34 of Set 2 | cabedelo
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | karpogory
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | iracoubo
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | mentakab
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | sao miguel do araguaia
# Processing Record 44 of Set 2 | namtsy
# Processing Record 45 of Set 2 | nikolskoye
# Processing Record 46 of Set 2 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 2 | tahoua
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | sao filipe
# Processing Record 50 of Set 2 | los llanos de aridane
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | bluff
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | leninskoye
# Processing Record 6 of Set 3 | ponta do sol
# Processing Record 7 of Set 3 | daru
# Processing Record 8 of Set 3 | yeniseysk
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | richards bay
# Processing Record 11 of Set 3 | asau
# Processing Record 12 of Set 3 | kavaratti
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | port elizabeth
# Processing Record 15 of Set 3 | tasiilaq
# Processing Record 16 of Set 3 | luderitz
# Processing Record 17 of Set 3 | rodnykove
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | iskateley
# Processing Record 20 of Set 3 | clyde river
# Processing Record 21 of Set 3 | cape town
# Processing Record 22 of Set 3 | tyrma
# Processing Record 23 of Set 3 | mezen
# Processing Record 24 of Set 3 | esperance
# Processing Record 25 of Set 3 | katherine
# Processing Record 26 of Set 3 | jiuquan
# Processing Record 27 of Set 3 | floro
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | phnum penh
# City not found. Skipping...
# Processing Record 30 of Set 3 | ushtobe
# Processing Record 31 of Set 3 | gargzdai
# Processing Record 32 of Set 3 | uniontown
# Processing Record 33 of Set 3 | makakilo city
# Processing Record 34 of Set 3 | nakusp
# Processing Record 35 of Set 3 | hue
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | guelengdeng
# City not found. Skipping...
# Processing Record 38 of Set 3 | taksimo
# Processing Record 39 of Set 3 | biak
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | hualmay
# Processing Record 43 of Set 3 | aykhal
# Processing Record 44 of Set 3 | nantucket
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | gillette
# Processing Record 47 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | sao joao da barra
# Processing Record 50 of Set 3 | hobyo
# Processing Record 1 of Set 4 | panaba
# Processing Record 2 of Set 4 | puerto del rosario
# Processing Record 3 of Set 4 | llanes
# Processing Record 4 of Set 4 | havoysund
# Processing Record 5 of Set 4 | chiang rai
# Processing Record 6 of Set 4 | acapulco
# Processing Record 7 of Set 4 | ca mau
# Processing Record 8 of Set 4 | faanui
# Processing Record 9 of Set 4 | port hedland
# Processing Record 10 of Set 4 | ukiah
# Processing Record 11 of Set 4 | huarmey
# Processing Record 12 of Set 4 | namatanai
# Processing Record 13 of Set 4 | okhotsk
# Processing Record 14 of Set 4 | contamana
# Processing Record 15 of Set 4 | sibolga
# Processing Record 16 of Set 4 | kem
# Processing Record 17 of Set 4 | ponta delgada
# Processing Record 18 of Set 4 | magnor
# Processing Record 19 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 20 of Set 4 | nalut
# Processing Record 21 of Set 4 | nouakchott
# Processing Record 22 of Set 4 | timizart
# Processing Record 23 of Set 4 | shestakovo
# Processing Record 24 of Set 4 | sambava
# Processing Record 25 of Set 4 | dwarka
# Processing Record 26 of Set 4 | castro
# Processing Record 27 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 4 | alice springs
# Processing Record 29 of Set 4 | terney
# Processing Record 30 of Set 4 | manggar
# Processing Record 31 of Set 4 | maragogi
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | leningradskiy
# Processing Record 34 of Set 4 | atuona
# Processing Record 35 of Set 4 | torbay
# Processing Record 36 of Set 4 | olafsvik
# Processing Record 37 of Set 4 | elva
# Processing Record 38 of Set 4 | kalmunai
# Processing Record 39 of Set 4 | komsomolskiy
# Processing Record 40 of Set 4 | deqing
# Processing Record 41 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 4 | pochutla
# Processing Record 43 of Set 4 | ancud
# Processing Record 44 of Set 4 | hilo
# Processing Record 45 of Set 4 | christchurch
# Processing Record 46 of Set 4 | coquimbo
# Processing Record 47 of Set 4 | khuzdar
# Processing Record 48 of Set 4 | pimenteiras
# Processing Record 49 of Set 4 | laguna
# Processing Record 50 of Set 4 | paracambi
# Processing Record 1 of Set 5 | coihaique
# Processing Record 2 of Set 5 | panzhihua
# Processing Record 3 of Set 5 | ojinaga
# Processing Record 4 of Set 5 | vaitape
# Processing Record 5 of Set 5 | hovd
# Processing Record 6 of Set 5 | gat
# Processing Record 7 of Set 5 | mahebourg
# Processing Record 8 of Set 5 | sitka
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | barrow
# Processing Record 11 of Set 5 | maarianhamina
# Processing Record 12 of Set 5 | mormugao
# Processing Record 13 of Set 5 | hurghada
# Processing Record 14 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 5 | maningrida
# Processing Record 16 of Set 5 | puerto ayora
# Processing Record 17 of Set 5 | balikpapan
# Processing Record 18 of Set 5 | college
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | kuching
# Processing Record 21 of Set 5 | porto franco
# Processing Record 22 of Set 5 | kitzbuhel
# Processing Record 23 of Set 5 | amalapuram
# Processing Record 24 of Set 5 | nabire
# Processing Record 25 of Set 5 | trinidad
# Processing Record 26 of Set 5 | dongsheng
# Processing Record 27 of Set 5 | mumford
# Processing Record 28 of Set 5 | huazhou
# Processing Record 29 of Set 5 | coahuayana
# Processing Record 30 of Set 5 | kashi
# Processing Record 31 of Set 5 | meulaboh
# Processing Record 32 of Set 5 | amapa
# Processing Record 33 of Set 5 | manjacaze
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | xai-xai
# Processing Record 36 of Set 5 | varhaug
# Processing Record 37 of Set 5 | mendeleyevsk
# Processing Record 38 of Set 5 | upernavik
# Processing Record 39 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 5 | tabou
# Processing Record 41 of Set 5 | north bend
# Processing Record 42 of Set 5 | urussanga
# Processing Record 43 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 5 | benghazi
# Processing Record 45 of Set 5 | kencong
# Processing Record 46 of Set 5 | beyneu
# Processing Record 47 of Set 5 | saint-augustin
# Processing Record 48 of Set 5 | ugoofaaru
# Processing Record 49 of Set 5 | ngunguru
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | qeshm
# Processing Record 2 of Set 6 | hilton head island
# Processing Record 3 of Set 6 | ambilobe
# Processing Record 4 of Set 6 | puerto escondido
# Processing Record 5 of Set 6 | severo-kurilsk
# Processing Record 6 of Set 6 | champerico
# Processing Record 7 of Set 6 | sao jose da coroa grande
# Processing Record 8 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 6 | mount isa
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | alta floresta
# Processing Record 12 of Set 6 | xining
# Processing Record 13 of Set 6 | beringovskiy
# Processing Record 14 of Set 6 | arkhangelsk
# Processing Record 15 of Set 6 | vila velha
# Processing Record 16 of Set 6 | canutama
# Processing Record 17 of Set 6 | auki
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | grevesmuhlen
# Processing Record 20 of Set 6 | dzaoudzi
# Processing Record 21 of Set 6 | yellowknife
# Processing Record 22 of Set 6 | mananjary
# Processing Record 23 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 24 of Set 6 | naze
# Processing Record 25 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 6 | taltal
# Processing Record 27 of Set 6 | nome
# Processing Record 28 of Set 6 | brigantine
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 6 | sobolevo
# Processing Record 32 of Set 6 | verkhnevilyuysk
# Processing Record 33 of Set 6 | sicuani
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | new iberia
# Processing Record 36 of Set 6 | belaya gora
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | ozernovskiy
# Processing Record 39 of Set 6 | zeya
# Processing Record 40 of Set 6 | olbia
# Processing Record 41 of Set 6 | piopio
# Processing Record 42 of Set 6 | east london
# Processing Record 43 of Set 6 | fort-shevchenko
# Processing Record 44 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 6 | berck
# Processing Record 46 of Set 6 | papetoai
# Processing Record 47 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 6 | maraa
# Processing Record 49 of Set 6 | norman wells
# Processing Record 50 of Set 6 | san joaquin
# Processing Record 1 of Set 7 | khatanga
# Processing Record 2 of Set 7 | aswan
# Processing Record 3 of Set 7 | balingasay
# Processing Record 4 of Set 7 | guaruja
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | antipino
# Processing Record 7 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 7 | guder
# Processing Record 9 of Set 7 | prokhorovka
# Processing Record 10 of Set 7 | lakatoro
# Processing Record 11 of Set 7 | narsaq
# Processing Record 12 of Set 7 | dillon
# Processing Record 13 of Set 7 | sri aman
# Processing Record 14 of Set 7 | sindou
# Processing Record 15 of Set 7 | saldanha
# Processing Record 16 of Set 7 | saint stephen
# Processing Record 17 of Set 7 | tuy hoa
# Processing Record 18 of Set 7 | tabuk
# Processing Record 19 of Set 7 | kovur
# Processing Record 20 of Set 7 | chapais
# Processing Record 21 of Set 7 | killybegs
# Processing Record 22 of Set 7 | pershotravneve
# Processing Record 23 of Set 7 | vyshhorod
# Processing Record 24 of Set 7 | lotofaga
# Processing Record 25 of Set 7 | agadez
# Processing Record 26 of Set 7 | tailai
# Processing Record 27 of Set 7 | nhulunbuy
# Processing Record 28 of Set 7 | alyangula
# Processing Record 29 of Set 7 | manokwari
# Processing Record 30 of Set 7 | leshukonskoye
# Processing Record 31 of Set 7 | keansburg
# Processing Record 32 of Set 7 | pandamatenga
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | mnogovershinnyy
# Processing Record 35 of Set 7 | yulara
# Processing Record 36 of Set 7 | broken hill
# Processing Record 37 of Set 7 | okha
# Processing Record 38 of Set 7 | vincennes
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | neiafu
# Processing Record 41 of Set 7 | kahului
# Processing Record 42 of Set 7 | cravo norte
# Processing Record 43 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 7 | saint-pierre
# Processing Record 45 of Set 7 | salinopolis
# Processing Record 46 of Set 7 | kismayo
# Processing Record 47 of Set 7 | bonthe
# Processing Record 48 of Set 7 | kyrylivka
# Processing Record 49 of Set 7 | ouallam
# Processing Record 50 of Set 7 | tadine
# Processing Record 1 of Set 8 | slonim
# Processing Record 2 of Set 8 | hamilton
# Processing Record 3 of Set 8 | codrington
# Processing Record 4 of Set 8 | fare
# Processing Record 5 of Set 8 | ilhabela
# Processing Record 6 of Set 8 | cap malheureux
# Processing Record 7 of Set 8 | longyearbyen
# Processing Record 8 of Set 8 | pimenta bueno
# Processing Record 9 of Set 8 | praya
# Processing Record 10 of Set 8 | grover beach
# Processing Record 11 of Set 8 | coos bay
# Processing Record 12 of Set 8 | lahat
# Processing Record 13 of Set 8 | lasa
# Processing Record 14 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 8 | bandarbeyla
# Processing Record 16 of Set 8 | winneba
# Processing Record 17 of Set 8 | saint-georges
# Processing Record 18 of Set 8 | tessalit
# Processing Record 19 of Set 8 | la union
# Processing Record 20 of Set 8 | gardner
# Processing Record 21 of Set 8 | yankton
# Processing Record 22 of Set 8 | isiro
# Processing Record 23 of Set 8 | katsuura
# Processing Record 24 of Set 8 | tevaitoa
# Processing Record 25 of Set 8 | seddon
# Processing Record 26 of Set 8 | vizinga
# Processing Record 27 of Set 8 | samagaltay
# Processing Record 28 of Set 8 | matara
# Processing Record 29 of Set 8 | kununurra
# Processing Record 30 of Set 8 | sudislavl
# Processing Record 31 of Set 8 | roches noires
# City not found. Skipping...
# Processing Record 32 of Set 8 | punta alta
# Processing Record 33 of Set 8 | usinsk
# Processing Record 34 of Set 8 | quatre cocos
# Processing Record 35 of Set 8 | cururupu
# Processing Record 36 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 8 | cobija
# Processing Record 39 of Set 8 | eureka
# Processing Record 40 of Set 8 | dungarpur
# Processing Record 41 of Set 8 | carupano
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | labuhan
# Processing Record 44 of Set 8 | issoire
# Processing Record 45 of Set 8 | kangaatsiaq
# Processing Record 46 of Set 8 | jacksonville
# Processing Record 47 of Set 8 | siderno
# Processing Record 48 of Set 8 | cidreira
# Processing Record 49 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 50 of Set 8 | pevek
# Processing Record 1 of Set 9 | nelson bay
# Processing Record 2 of Set 9 | klaksvik
# Processing Record 3 of Set 9 | verkhnyaya inta
# Processing Record 4 of Set 9 | mahon
# Processing Record 5 of Set 9 | ahipara
# Processing Record 6 of Set 9 | olinda
# Processing Record 7 of Set 9 | saint anthony
# Processing Record 8 of Set 9 | manuk mangkaw
# Processing Record 9 of Set 9 | sur
# Processing Record 10 of Set 9 | siparia
# Processing Record 11 of Set 9 | kyzyl
# Processing Record 12 of Set 9 | ternate
# Processing Record 13 of Set 9 | camacha
# Processing Record 14 of Set 9 | sabha
# Processing Record 15 of Set 9 | porto nacional
# Processing Record 16 of Set 9 | maneadero
# Processing Record 17 of Set 9 | valparaiso
# Processing Record 18 of Set 9 | roald
# Processing Record 19 of Set 9 | arlit
# Processing Record 20 of Set 9 | kisangani
# Processing Record 21 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 9 | ambon
# Processing Record 23 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 24 of Set 9 | zhuanghe
# Processing Record 25 of Set 9 | garsten
# Processing Record 26 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | chilca
# Processing Record 28 of Set 9 | la grande
# Processing Record 29 of Set 9 | bonnyville
# Processing Record 30 of Set 9 | la serena
# Processing Record 31 of Set 9 | livani
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | ulaanbaatar
# Processing Record 34 of Set 9 | marawi
# Processing Record 35 of Set 9 | tiarei
# Processing Record 36 of Set 9 | bull savanna
# Processing Record 37 of Set 9 | lata
# Processing Record 38 of Set 9 | san juan del sur
# Processing Record 39 of Set 9 | nazare
# Processing Record 40 of Set 9 | khotynets
# Processing Record 41 of Set 9 | pundaguitan
# Processing Record 42 of Set 9 | flinders
# Processing Record 43 of Set 9 | amol
# Processing Record 44 of Set 9 | manzanillo
# Processing Record 45 of Set 9 | seoul
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 48 of Set 9 | yerbogachen
# Processing Record 49 of Set 9 | krasnoselkup
# Processing Record 50 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 1 of Set 10 | andros town
# Processing Record 2 of Set 10 | tundla
# Processing Record 3 of Set 10 | kotovo
# Processing Record 4 of Set 10 | bucerias
# Processing Record 5 of Set 10 | souillac
# Processing Record 6 of Set 10 | lubao
# Processing Record 7 of Set 10 | batemans bay
# Processing Record 8 of Set 10 | along
# Processing Record 9 of Set 10 | mantua
# Processing Record 10 of Set 10 | liku
# Processing Record 11 of Set 10 | ust-ilimsk
# Processing Record 12 of Set 10 | verkhoyansk
# Processing Record 13 of Set 10 | pokosnoye
# Processing Record 14 of Set 10 | bud
# Processing Record 15 of Set 10 | loa janan
# Processing Record 16 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 10 | san jeronimo
# Processing Record 18 of Set 10 | uva
# Processing Record 19 of Set 10 | portland
# Processing Record 20 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 10 | palauig
# Processing Record 22 of Set 10 | rabaul
# Processing Record 23 of Set 10 | solenzo
# Processing Record 24 of Set 10 | krasnoyarskaya
# Processing Record 25 of Set 10 | kenai
# Processing Record 26 of Set 10 | hunsur
# Processing Record 27 of Set 10 | benidorm
# Processing Record 28 of Set 10 | abomsa
# Processing Record 29 of Set 10 | ostrovnoy
# Processing Record 30 of Set 10 | almaznyy
# Processing Record 31 of Set 10 | fazalpur
# Processing Record 32 of Set 10 | sarahan
# Processing Record 33 of Set 10 | cordele
# Processing Record 34 of Set 10 | tura
# Processing Record 35 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 10 | waw
# Processing Record 37 of Set 10 | husavik
# Processing Record 38 of Set 10 | dingle
# Processing Record 39 of Set 10 | tigil
# Processing Record 40 of Set 10 | jibuti
# Processing Record 41 of Set 10 | tucupita
# Processing Record 42 of Set 10 | diamantino
# Processing Record 43 of Set 10 | rocha
# Processing Record 44 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 45 of Set 10 | bubaque
# Processing Record 46 of Set 10 | maumere
# Processing Record 47 of Set 10 | margate
# Processing Record 48 of Set 10 | lorengau
# Processing Record 49 of Set 10 | moen
# Processing Record 50 of Set 10 | abalak
# Processing Record 1 of Set 11 | swidwin
# Processing Record 2 of Set 11 | mascote
# Processing Record 3 of Set 11 | boddam
# Processing Record 4 of Set 11 | chernyshevskiy
# Processing Record 5 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 6 of Set 11 | bac lieu
# Processing Record 7 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 11 | alexandria
# Processing Record 9 of Set 11 | chongqing
# Processing Record 10 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | weston
# Processing Record 12 of Set 11 | jacareacanga
# Processing Record 13 of Set 11 | presidencia roque saenz pena
# Processing Record 14 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 11 | paytug
# City not found. Skipping...
# Processing Record 16 of Set 11 | bosaso
# Processing Record 17 of Set 11 | caravelas
# Processing Record 18 of Set 11 | oranjemund
# Processing Record 19 of Set 11 | azare
# Processing Record 20 of Set 11 | lompoc
# Processing Record 21 of Set 11 | kayes
# Processing Record 22 of Set 11 | cheremukhovo
# Processing Record 23 of Set 11 | denpasar
# Processing Record 24 of Set 11 | solon
# Processing Record 25 of Set 11 | chumikan
# Processing Record 26 of Set 11 | amahai
# Processing Record 27 of Set 11 | warman
# Processing Record 28 of Set 11 | portpatrick
# City not found. Skipping...
# Processing Record 29 of Set 11 | sept-iles
# Processing Record 30 of Set 11 | tocopilla
# Processing Record 31 of Set 11 | kaitangata
# Processing Record 32 of Set 11 | bossangoa
# Processing Record 33 of Set 11 | egvekinot
# Processing Record 34 of Set 11 | innisfail
# Processing Record 35 of Set 11 | te anau
# Processing Record 36 of Set 11 | mateare
# Processing Record 37 of Set 11 | pangnirtung
# Processing Record 38 of Set 11 | beian
# Processing Record 39 of Set 11 | kailua
# Processing Record 40 of Set 11 | port keats
# Processing Record 41 of Set 11 | ngama
# Processing Record 42 of Set 11 | bengkulu
# Processing Record 43 of Set 11 | pacifica
# Processing Record 44 of Set 11 | fuerte olimpo
# Processing Record 45 of Set 11 | kerema
# Processing Record 46 of Set 11 | baruun-urt
# Processing Record 47 of Set 11 | am timan
# Processing Record 48 of Set 11 | bay roberts
# Processing Record 49 of Set 11 | nizhniy bestyakh
# Processing Record 50 of Set 11 | koulamoutou
# Processing Record 1 of Set 12 | tromso
# Processing Record 2 of Set 12 | cimahi
# Processing Record 3 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 12 | bilibino
# Processing Record 5 of Set 12 | nieuw amsterdam
# Processing Record 6 of Set 12 | kamaishi
# Processing Record 7 of Set 12 | prince rupert
# Processing Record 8 of Set 12 | terrace bay
# Processing Record 9 of Set 12 | oiso
# Processing Record 10 of Set 12 | sao gabriel da cachoeira
# Processing Record 11 of Set 12 | necochea
# Processing Record 12 of Set 12 | tahta
# Processing Record 13 of Set 12 | glenwood springs
# Processing Record 14 of Set 12 | natitingou
# Processing Record 15 of Set 12 | ouango
# Processing Record 16 of Set 12 | balao
# Processing Record 17 of Set 12 | suntar
# Processing Record 18 of Set 12 | nuuk
# Processing Record 19 of Set 12 | vagur
# Processing Record 20 of Set 12 | nizhniy tagil
# Processing Record 21 of Set 12 | faya
# Processing Record 22 of Set 12 | banda aceh
# Processing Record 23 of Set 12 | khani
# Processing Record 24 of Set 12 | vila franca do campo
# Processing Record 25 of Set 12 | hibbing
# Processing Record 26 of Set 12 | beloha
# Processing Record 27 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | shahrud
# Processing Record 29 of Set 12 | sherbakul
# Processing Record 30 of Set 12 | boralday
# Processing Record 31 of Set 12 | caldwell
# Processing Record 32 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 33 of Set 12 | togur
# Processing Record 34 of Set 12 | muli
# Processing Record 35 of Set 12 | kasama
# Processing Record 36 of Set 12 | ondo
# Processing Record 37 of Set 12 | peace river
# Processing Record 38 of Set 12 | mosquera
# Processing Record 39 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 40 of Set 12 | chipata
# Processing Record 41 of Set 12 | jieshou
# Processing Record 42 of Set 12 | cavalcante
# Processing Record 43 of Set 12 | the valley
# Processing Record 44 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 12 | eyl
# Processing Record 46 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 12 | marathon
# Processing Record 48 of Set 12 | archidona
# Processing Record 49 of Set 12 | mme
# City not found. Skipping...
# Processing Record 50 of Set 12 | puerto suarez
# Processing Record 1 of Set 13 | neepawa
# Processing Record 2 of Set 13 | thinadhoo
# Processing Record 3 of Set 13 | batticaloa
# Processing Record 4 of Set 13 | pedro betancourt
# Processing Record 5 of Set 13 | orlik
# Processing Record 6 of Set 13 | quelimane
# Processing Record 7 of Set 13 | caluquembe
# Processing Record 8 of Set 13 | hampton
# Processing Record 9 of Set 13 | ocos
# Processing Record 10 of Set 13 | guarapari
# Processing Record 11 of Set 13 | mitu
# Processing Record 12 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 13 of Set 13 | cubuk
# Processing Record 14 of Set 13 | san ignacio
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | yola
# Processing Record 17 of Set 13 | geilenkirchen
# Processing Record 18 of Set 13 | puerto carreno
# Processing Record 19 of Set 13 | bumba
# Processing Record 20 of Set 13 | bela
# Processing Record 21 of Set 13 | sao francisco
# Processing Record 22 of Set 13 | sharjah
# Processing Record 23 of Set 13 | inuvik
# Processing Record 24 of Set 13 | agua verde
# Processing Record 25 of Set 13 | marsh harbour
# Processing Record 26 of Set 13 | hofn
# Processing Record 27 of Set 13 | hadrut
# Processing Record 28 of Set 13 | mlonggo
# Processing Record 29 of Set 13 | ejby
# Processing Record 30 of Set 13 | baracoa
# Processing Record 31 of Set 13 | poya
# Processing Record 32 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 13 | kuna
# Processing Record 34 of Set 13 | farah
# Processing Record 35 of Set 13 | sorong
# Processing Record 36 of Set 13 | oksfjord
# Processing Record 37 of Set 13 | hit
# Processing Record 38 of Set 13 | taywarah
# Processing Record 39 of Set 13 | turiacu
# Processing Record 40 of Set 13 | khash
# Processing Record 41 of Set 13 | itarema
# Processing Record 42 of Set 13 | morondava
# Processing Record 43 of Set 13 | korla
# Processing Record 44 of Set 13 | ranchi
# Processing Record 45 of Set 13 | semnan
# Processing Record 46 of Set 13 | altay
# Processing Record 47 of Set 13 | belchatow
# Processing Record 48 of Set 13 | kushiro
# Processing Record 49 of Set 13 | det udom
# Processing Record 50 of Set 13 | rayachoti
# Processing Record 1 of Set 14 | bodden town
# Processing Record 2 of Set 14 | xichang
# Processing Record 3 of Set 14 | okoneshnikovo
# Processing Record 4 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 14 | honiara
# Processing Record 6 of Set 14 | maturin
# Processing Record 7 of Set 14 | axim
# Processing Record 8 of Set 14 | guiratinga
# Processing Record 9 of Set 14 | palu
# Processing Record 10 of Set 14 | bereda
# Processing Record 11 of Set 14 | madimba
# Processing Record 12 of Set 14 | waounde
# Processing Record 13 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 14 | springfield
# Processing Record 15 of Set 14 | road town
# Processing Record 16 of Set 14 | ust-maya
# Processing Record 17 of Set 14 | gizo
# Processing Record 18 of Set 14 | khasan
# Processing Record 19 of Set 14 | itoman
# Processing Record 20 of Set 14 | vanimo
# Processing Record 21 of Set 14 | santiago
# Processing Record 22 of Set 14 | leh
# Processing Record 23 of Set 14 | callaway
# Processing Record 24 of Set 14 | pimentel
# Processing Record 25 of Set 14 | suwa
# Processing Record 26 of Set 14 | dunmore east
# Processing Record 27 of Set 14 | hay river
# Processing Record 28 of Set 14 | ginda
# Processing Record 29 of Set 14 | bambanglipuro
# Processing Record 30 of Set 14 | thunder bay
# Processing Record 31 of Set 14 | lazaro cardenas
# Processing Record 32 of Set 14 | bibiani
# Processing Record 33 of Set 14 | madang
# Processing Record 34 of Set 14 | lyubinskiy
# Processing Record 35 of Set 14 | nyimba
# Processing Record 36 of Set 14 | kuruman
# Processing Record 37 of Set 14 | esfahan
# Processing Record 38 of Set 14 | lagunas
# Processing Record 39 of Set 14 | yangjiang
# Processing Record 40 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 14 | chaumont
# Processing Record 42 of Set 14 | rutland
# Processing Record 43 of Set 14 | myitkyina
# Processing Record 44 of Set 14 | bushehr
# Processing Record 45 of Set 14 | kirkland lake
# Processing Record 46 of Set 14 | santa cruz
# Processing Record 47 of Set 14 | newton
# Processing Record 48 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 14 | mayumba
# Processing Record 50 of Set 14 | stornoway
# Processing Record 1 of Set 15 | cockburn town
# Processing Record 2 of Set 15 | mwense
# Processing Record 3 of Set 15 | bairiki
# Processing Record 4 of Set 15 | gushi
# Processing Record 5 of Set 15 | huaral
# Processing Record 6 of Set 15 | parrita
# Processing Record 7 of Set 15 | adrar
# Processing Record 8 of Set 15 | rognan
# Processing Record 9 of Set 15 | boende
# Processing Record 10 of Set 15 | bontang
# Processing Record 11 of Set 15 | hirado
# Processing Record 12 of Set 15 | ocean city
# Processing Record 13 of Set 15 | arauca
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | lovozero
# Processing Record 16 of Set 15 | leshan
# Processing Record 17 of Set 15 | ormara
# Processing Record 18 of Set 15 | xaltianguis
# Processing Record 19 of Set 15 | abbeville
# Processing Record 20 of Set 15 | honningsvag
# Processing Record 21 of Set 15 | orda
# Processing Record 22 of Set 15 | hiriyur
# Processing Record 23 of Set 15 | sira
# Processing Record 24 of Set 15 | san carlos park
# Processing Record 25 of Set 15 | rennes
# Processing Record 26 of Set 15 | zhicheng
# Processing Record 27 of Set 15 | hukuntsi
# Processing Record 28 of Set 15 | zabol
# Processing Record 29 of Set 15 | wanning
# Processing Record 30 of Set 15 | nizwa
# Processing Record 31 of Set 15 | wad rawah
# Processing Record 32 of Set 15 | tabursuq
# Processing Record 33 of Set 15 | umm kaddadah
# Processing Record 34 of Set 15 | bima
# Processing Record 35 of Set 15 | visby
# Processing Record 36 of Set 15 | colares
# Processing Record 37 of Set 15 | nieves
# Processing Record 38 of Set 15 | buraydah
# Processing Record 39 of Set 15 | srivardhan
# Processing Record 40 of Set 15 | jiangyou
# Processing Record 41 of Set 15 | kattivakkam
# Processing Record 42 of Set 15 | baboua
# City not found. Skipping...
# Processing Record 43 of Set 15 | galveston
# Processing Record 44 of Set 15 | zyryanka
# Processing Record 45 of Set 15 | urumqi
# Processing Record 46 of Set 15 | unguia
# Processing Record 47 of Set 15 | lagoa
# Processing Record 48 of Set 15 | hengshui
# Processing Record 49 of Set 15 | riyadh
# Processing Record 50 of Set 15 | tautira
# Processing Record 1 of Set 16 | celestun
# Processing Record 2 of Set 16 | port said
# Processing Record 3 of Set 16 | karimnagar
# Processing Record 4 of Set 16 | gamboma
# Processing Record 5 of Set 16 | umm lajj
# Processing Record 6 of Set 16 | pushchino
# Processing Record 7 of Set 16 | maldonado
# Processing Record 8 of Set 16 | tukrah
# Processing Record 9 of Set 16 | kita
# Processing Record 10 of Set 16 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 16 | goksun
# Processing Record 12 of Set 16 | aksarka
# Processing Record 13 of Set 16 | harper
# Processing Record 14 of Set 16 | abu zabad
# Processing Record 15 of Set 16 | turukhansk
# Processing Record 16 of Set 16 | fatikchhari
# City not found. Skipping...
# Processing Record 17 of Set 16 | ixhuatan
# Processing Record 18 of Set 16 | wilmington
# Processing Record 19 of Set 16 | liaqatabad
# Processing Record 20 of Set 16 | berdigestyakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Nome  64.5011 -165.4064     49.15        93          90
# 1  Glyadyanskoye  54.9075   65.0883     56.98        59          76
# 2     Nikolskoye  59.7035   30.7861     76.89        67          25
# 3         Vanimo  -2.6741  141.3028     75.96        84          10
# 4    New Norfolk -42.7826  147.0587     53.10        81          98
# 5      Nantucket  41.2835  -70.0995     83.25        85           1
# 6     Winnemucca  40.9730 -117.7357     93.25        15           1
# 7         Albany  42.6001  -73.9662     86.58        53           1
# 8          Picsi  -6.7178  -79.7697     73.24        64          40
# 9        Mersing   2.4312  103.8405     78.12        89          70
#
#    Wind Speed Current Description Country
# 0        8.05          light rain      US
# 1        5.82       broken clouds      RU
# 2        3.85    scattered clouds      RU
# 3        4.68           clear sky      PG
# 4        3.00          light rain      AU
# 5       11.50           clear sky      US
# 6        4.61                haze      US
# 7        1.99           clear sky      US
# 8        9.22    scattered clouds      PE
# 9        6.93       broken clouds      MY

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Nome      US  64.5011 -165.4064     49.15        93          90
# 1  Glyadyanskoye      RU  54.9075   65.0883     56.98        59          76
# 2     Nikolskoye      RU  59.7035   30.7861     76.89        67          25
# 3         Vanimo      PG  -2.6741  141.3028     75.96        84          10
# 4    New Norfolk      AU -42.7826  147.0587     53.10        81          98
#
#    Wind Speed Current Description
# 0        8.05          light rain
# 1        5.82       broken clouds
# 2        3.85    scattered clouds
# 3        4.68           clear sky
# 4        3.00          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
